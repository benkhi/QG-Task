# %% [markdown]
# ## Get ClinicalTerms from ClinicalTrials
# ### Operation run in background even if JupyterLab is broken..

# %%
from tqdm import tqdm
import sys
import os

# 파일 목록 로드 /home2/dalya/CTs/CTs-processed-v1/list
with open("/home2/TREC_collections/TREC-CT/filelist", 'r') as f:
    f_list = f.readlines()

len_total = len(f_list)
print(len_total, f_list[1])
# Out:
# 375580 ./ClinicalTrials.2021-04-27.part1/NCT0081xxxx/NCT00816738.xml

# %%
#import xml.etree.ElementTree as ET
#f_path = "/home2/ukyoung/my-python/TREC/문서전처리_0712/CTs-processed-v1"
f_path = "/home2/dalya/TREC/CTs-processed-v1/"

# find last continued point
_f = 'NCT00159172.xml'
for idx in range(1, len_total + 1):
    #print(idx, end=' ')
    if _f == f_list[idx][46:-1]:
        print(idx)
        break
# Out:
# 24658

# %%
#import xml.etree.ElementTree as ET
#f_path = "/home2/ukyoung/my-python/TREC/문서전처리_0712/CTs-processed-v1"
from datetime import datetime
start = datetime.now()

f_path = "/home2/dalya/TREC/CTs-processed-v1/"

for idx in range(24658, len_total + 1):
    doc_path = f_path + f_list[idx][1:-1]
    try:
        script_descriptor = open("ClinicalBERT_BIO.py")
        a_script = script_descriptor.read()
        sys.argv = ["ClinicalBERT_BIO.py", doc_path]

        exec(a_script)
        script_descriptor.close()
    except:
        print(str(idx) + ' error..', end=' ')
        #pass
# Out:
# /home/dalya/anaconda3/envs/dalya/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/dalya/anaconda3/envs/dalya/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/dalya/anaconda3/envs/dalya/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/dalya/anaconda3/envs/dalya/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/dalya/anaconda3/envs/dalya/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/dalya/anaconda3/envs/dalya/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/dalya/anaconda3/envs/dalya/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/dalya/anaconda3/envs/dalya/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/dalya/anaconda3/envs/dalya/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/dalya/anaconda3/envs/dalya/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/dalya/anaconda3/envs/dalya/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/dalya/anaconda3/envs/dalya/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/dalya/anaconda3/envs/dalya/lib/python3.6/site-packages/sklearn/base.py:253: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.19.1 when using version 0.20.4. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# WARNING:tensorflow:From /home/dalya/anaconda3/envs/dalya/lib/python3.6/site-packages/tensorflow/python/util/dispatch.py:180: calling squeeze (from tensorflow.python.ops.array_ops) with squeeze_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the `axis` argument instead
# WARNING:tensorflow:From /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/bilm.py:991: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/bilm.py:1036: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /home/dalya/anaconda3/envs/dalya/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/dalya/anaconda3/envs/dalya/lib/python3.6/site-packages/tensorflow/python/ops/rnn_cell_impl.py:961: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/dalya/anaconda3/envs/dalya/lib/python3.6/site-packages/tensorflow/python/ops/rnn.py:244: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/elmo_vector.py:21: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/elmo_vector.py:24: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/elmo_vector.py:25: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/pipeline.py:39: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /home/dalya/anaconda3/envs/dalya/lib/python3.6/site-packages/tensorflow/python/data/ops/dataset_ops.py:494: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# WARNING:tensorflow:From /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/pipeline.py:47: The name tf.Dimension is deprecated. Please use tf.compat.v1.Dimension instead.
#
# WARNING:tensorflow:From /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/pipeline.py:49: DatasetV1.make_initializable_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_initializable_iterator(dataset)`.
# WARNING:tensorflow:From /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/model.py:56: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/model.py:62: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/model.py:66: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# WARNING:tensorflow:From /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/model.py:88: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/pipeline.py:54: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From /home/dalya/anaconda3/envs/dalya/lib/python3.6/site-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# <Doc nct_id="NCT00159172">
#   <title>                        Safety O
#                             and O
#                        Efficacy O
#                              of O
#                           Motor B-treatment
#                          Cortex I-treatment
#                     Stimulation I-treatment
#                              in O
#                             the O
#                       Treatment O
#                              of O
#                        Advanced B-problem
#                       Parkinson I-problem
#                         Disease I-problem
# </title>
#   <official_title>                         Phase B-test
#                               1 O
#                           Study O
#                              of O
#                           Motor O
#                          Cortex O
#                     Stimulation O
#                              in O
#                             the O
#                       Treatment O
#                              of O
#                        Advanced B-problem
#                       Parkinson I-problem
#                         Disease I-problem
# </official_title>
#   <summary>                          side B-problem
#                         effects I-problem
#                            with O
#                    dopaminergic B-treatment
#                       treatment I-treatment
#                               . O
# </summary>
#   <description>                     morbidity B-problem
#                            risk I-problem
#                               . O
# </description>
#   <condition>                     Parkinson B-problem
#                         Disease I-problem
# </condition>
#   <inclusion_criteria>                         score O
#                              in O
#                        off-drug O
#                           stage O
# </inclusion_criteria>
#   <exclusion_criteria>                        kidney B-problem
#                     dysfunction I-problem
#                               ) O
#                            with O
#                               a B-problem
#                          higher I-problem
#                        surgical I-problem
#                            risk I-problem
# </exclusion_criteria>
# </Doc>
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# <Doc nct_id="NCT00150670">
#   <title>                    Randomized O
#                           Phase O
#                             III O
#                           Study O
#                              of O
#                            TS-1 O
#                           Alone O
#                          Versus O
#                            TS-1 B-problem
#                            Plus I-problem
#                            CDDP I-problem
#                              in O
#                        Advanced B-problem
#                         Gastric I-problem
#                          Cancer I-problem
# </title>
#   <official_title>                    Randomized O
#                           Phase O
#                             III O
#                           Study O
#                              of O
#                            TS-1 O
#                           Alone O
#                          Versus O
#                            TS-1 B-problem
#                            Plus I-problem
#                            CDDP I-problem
#                              in O
#                        Advanced B-problem
#                         Gastric I-problem
#                          Cancer I-problem
# </official_title>
#   <summary>                      compared O
#                            with O
#                             the B-treatment
#                     monotherapy I-treatment
#                              by O
#                            TS-1 O
#                           alone O
#                               . O
# </summary>
#   <description>                             2 O
#                           years O
#                            from O
#                             the O
#                             day O
#                            they O
#                    participates O
#                              in O
#                            this B-test
#                           study I-test
#                               . O
# </description>
#   <condition>                       Gastric B-problem
#                          Cancer I-problem
# </condition>
#   <inclusion_criteria>                             - O
#                           Renal B-test
#                          Plasma I-test
#                      creatinine I-test
#                               ≤ O
#                             ULN B-test
#                      Creatinine B-test
#                       clearance I-test
#                               ≥ I-test
#                              50 O
#                          mL/min O
# </inclusion_criteria>
#   <exclusion_criteria>                             - O
#                         Ascites B-problem
#                       requiring O
#                        drainage B-treatment
# </exclusion_criteria>
# </Doc>
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# 24660 error.. INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# 24661 error.. INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# <Doc nct_id="NCT00155441">
#   <title>                       Effects O
#                              of O
#            Cognitive-Behavioral B-treatment
#                         Therapy I-treatment
#                              on O
#                           Sleep B-problem
#                     Disturbance I-problem
#                              in O
#                      Peritoneal O
#                        Dialysis O
#                        Patients O
# </title>
#   <official_title>                       Effects O
#                              of O
#            Cognitive-Behavioral B-treatment
#                         Therapy I-treatment
#                              on O
#                           Sleep B-problem
#                     Disturbance I-problem
#                              in O
#                      Peritoneal O
#                        Dialysis O
#                        Patients O
# </official_title>
#   <summary>                       chronic B-problem
#                      peritoneal I-problem
#                        dialysis I-problem
#                        patients I-problem
#                               . O
# </summary>
#   <description>                      baseline O
#                               , O
#                          before O
#                             and O
#                           after O
#                         therapy B-treatment
#                               . O
# </description>
#   <condition>                         Sleep B-problem
#                       Disorders I-problem
# </condition>
#   <inclusion_criteria>                             - O
#                            Have O
#                           sleep B-problem
#                     disturbance I-problem
#                    subjectively O
# </inclusion_criteria>
#   <exclusion_criteria>                             - O
#                   Participation O
#                              in O
#                         another B-test
#                           study I-test
#                            that O
#                           would O
#                       interfere O
#                            with O
#                             the O
#                         outcome O
#                              of O
#                            this B-test
#                           study I-test
# </exclusion_criteria>
# </Doc>
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# 24663 error.. INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# 24664 error.. INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# 24665 error.. INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# 24666 error.. INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# 24667 error.. INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# 24668 error.. INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# 24669 error.. INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# <Doc nct_id="NCT00151645">
#   <title>                      Efficacy O
#                              of O
#                       Activated B-problem
#                     Lymphocytes I-problem
#                              in O
#                           Renal B-problem
#                            Cell I-problem
#                       Carcinoma I-problem
#                               . O
# </title>
#   <official_title>                             A B-test
#                  Non-Randomized I-test
#                           Phase I-test
#                              II O
#                           Trial O
#                               . O
# </official_title>
#   <summary>                  interferon-α B-treatment
#                             and O
#                   interleukin-2 B-treatment
#                               . O
# </summary>
#   <description>                  characterize O
#                    functionally O
#                             and O
#                  phenotypically O
#                        injected I-problem
#                           cells I-problem
#                               . O
# </description>
#   <condition>                    Metastatic B-problem
#                           Renal I-problem
#                            Cell I-problem
#                       Carcinoma I-problem
# </condition>
#   <inclusion_criteria>                             - O
#                        Informed O
#                         written O
#                         consent O
# </inclusion_criteria>
#   <exclusion_criteria>                             - O
#                  Corticotherapy B-treatment
# </exclusion_criteria>
# </Doc>
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# <Doc nct_id="NCT00155194">
#   <title>                    Evaluation B-test
#                              of O
#                          Immune O
#                        Function O
#                              in O
#                         Biliary B-problem
#                         Atresia I-problem
#                        Children O
#                            With O
#                       Prolonged B-problem
#                        Jaundice I-problem
# </title>
#   <official_title>                      Impaired B-problem
#                    T-Lymphocyte I-problem
#                   Proliferative I-problem
#                        Function I-problem
#                              in O
#                         Biliary B-problem
#                         Atresia I-problem
#                        Children O
#                            With O
#                       Prolonged B-problem
#                        Jaundice I-problem
# </official_title>
#   <summary>                      systemic B-problem
#                        immunity I-problem
#                          defect I-problem
#                               . O
# </summary>
#   <description>                      function O
#                             and O
#                     cholestatic B-problem
#                        jaundice I-problem
#                               . O
# </description>
#   <condition>                       Biliary B-problem
#                         Atresia I-problem
# </condition>
#   <inclusion_criteria>                       Biliary O
#                        patients O
#                           older O
#                            than O
#                      1-year-old O
#                          status O
#                            post O
#                           Kasai B-treatment
#                       operation I-treatment
#                               . O
# </inclusion_criteria>
#   <exclusion_criteria>                           and O
#                         obvious B-problem
#                      infectious I-problem
#                         episode I-problem
#                               ( O
#                          within O
#                               2 O
#                           weeks O
#                               ) O
#                               . O
# </exclusion_criteria>
# </Doc>
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# <Doc nct_id="NCT00155155">
#   <title>                       Studies B-test
#                              of O
#                          Immune I-test
#                       Responses I-test
#                              in O
#                        Patients O
#                            With O
#                         Chronic B-problem
#                       Hepatitis I-problem
#                               B I-problem
# </title>
#   <official_title>                      Analysis B-test
#                              of O
#                    HBV-Specific B-problem
#                               T I-problem
#                            Cell I-problem
#                       Responses I-problem
#                             and O
#                      Regulatory B-test
#                               T I-test
#                           Cells I-test
#                              in O
#                        Patients O
#                            With O
#                         Chronic B-problem
#                       Hepatitis I-problem
#                               B I-problem
#                           Virus I-problem
#                       Infection I-problem
# </official_title>
#   <summary>                          CD8+ B-test
#                               T I-test
#                            cell I-test
#                       responses I-test
#                             and O
#                             the O
#                         clarify O
#                             the O
#                           roles O
#                              of O
#                      regulatory O
#                               T O
#                           cells O
#                               . O
# </summary>
#   <description>                     important O
#                            time O
#                          points O
#                               . O
# </description>
#   <condition>                     Hepatitis B-problem
#                               B I-problem
# </condition>
#   <inclusion_criteria>                             - O
#                        patients O
#                     chronically B-problem
#                        infected I-problem
#                            with O
#                       hepatitis B-problem
#                               B I-problem
#                           virus I-problem
# </inclusion_criteria>
#   <exclusion_criteria>                             - O
#                      coinfected B-problem
#                            with O
#                             HCV B-problem
#                              or O
#                             HIV B-problem
# </exclusion_criteria>
# </Doc>
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# 24673 error.. INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# 24674 error.. INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# <Doc nct_id="NCT00151255">
#   <title>                     All-Trans B-treatment
#                        Retinoic I-treatment
#                            Acid I-treatment
#                              in O
#                     Combination O
#                            With O
#                        Standard O
#                       Induction O
#                             and O
#                   Consolidation B-treatment
#                         Therapy I-treatment
#                              in O
#                           Older O
#                        Patients O
#                            With O
#                           Newly B-problem
#                       Diagnosed I-problem
#                           Acute I-problem
#                         Myeloid I-problem
#                        Leukemia I-problem
# </title>
#   <official_title>                         Phase O
#                             III O
#                               - O
#                           Study I-test
#                              on O
#                       All-Trans B-treatment
#                        Retinoic I-treatment
#                            Acid I-treatment
#                              in O
#                     Combination O
#                            With O
#                        Standard O
#                       Induction O
#                             and O
#                   Consolidation B-treatment
#                         Therapy I-treatment
#                              in O
#                           Older O
#                        Patients O
#                            With O
#                           Newly B-problem
#                       Diagnosed I-problem
#                           Acute I-problem
#                         Myeloid I-problem
#                        Leukemia I-problem
# </official_title>
#   <summary>                 consolidation B-treatment
#                         therapy I-treatment
#                              in O
#                           older O
#                        patients O
#                            with O
#                           newly B-problem
#                       diagnosed I-problem
#                           acute I-problem
#                         myeloid I-problem
#                        leukemia I-problem
#                               ( I-problem
#                             AML I-problem
#                               ) I-problem
#                               . O
# </summary>
#   <description>                             - O
#                            ATRA B-treatment
#                              15 O
#                           mg/m² O
#                            p.o. O
#                            days O
#                            4-28 O
# </description>
#   <condition>                         Acute B-problem
#                         Myeloid I-problem
#                        Leukemia I-problem
# </condition>
#   <inclusion_criteria>                      specimen O
#                            have O
#                              to O
#                              be O
#                       performed O
#                              at O
#                             the O
#                         central O
#                       reference O
#                    laboratories O
#                               . O
# </inclusion_criteria>
#   <exclusion_criteria>                             - O
#                     Performance O
#                          status O
#                             WHO O
#                               &gt; O
#                               2 O
# </exclusion_criteria>
# </Doc>
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# 24676 error.. INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# 24677 error.. INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# 24678 error.. INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# <Doc nct_id="NCT00150657">
#   <title>                         Study B-test
#                              of O
#         Carboplatin/Gemcitabine B-treatment
#                            Plus O
#                     Bevacizumab B-treatment
#                              in O
#                        Advanced B-problem
#                            Lung I-problem
#                          Cancer I-problem
# </title>
#   <official_title>                         Phase O
#                              II O
#                           Trial O
#                              of O
#         Carboplatin/Gemcitabine B-treatment
#                            Plus O
#                     Bevacizumab I-treatment
#                              in O
#                        Advanced B-problem
#                       Non-Small I-problem
#                            Cell I-problem
#                            Lung I-problem
#                          Cancer I-problem
# </official_title>
#   <summary>                             - O
#                             all O
#                        patients O
#                         receive O
#                             all B-treatment
#                           three I-treatment
#                           drugs I-treatment
#                               ; O
#                           there O
#                              is O
#                              no O
#                         placebo B-treatment
# </summary>
#   <description>                            IV O
#                             day O
#                               1 O
#                        repeated O
#                           every O
#                              21 O
#                            days O
#                             for O
#                               6 O
#                          cycles O
# </description>
#   <condition>                     Non-Small B-problem
#                            Cell I-problem
#                            Lung I-problem
#                          Cancer I-problem
# </condition>
#   <inclusion_criteria>                             - O
#                        informed O
#                         consent O
# </inclusion_criteria>
#   <exclusion_criteria>                             - O
#                        pregnant O
#                              or O
#                         nursing O
#                           women O
# </exclusion_criteria>
# </Doc>
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# 24680 error.. INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# 24681 error.. INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# <Doc nct_id="NCT00154674">
#   <title>                        Safety O
#                             and O
#                     Feasibility O
#                              of O
#                    Endovascular B-treatment
#                         Cooling I-treatment
#                          Device I-treatment
#                              in O
#                        Patients O
#                            With O
#                     Hypothermic B-problem
#                 Cardiopulmonary I-problem
#                   Resuscitation I-problem
# </title>
#   <official_title>                        Coming O
#                            From O
#                             the O
#                          N01061 O
#                           Trial O
#                               . O
# </official_title>
#   <summary>                       control O
#                               , O
#                              in O
#                             the O
#                         cardiac O
#                          arrest O
#                        patients O
#                               . O
# </summary>
#   <description>                           for O
#                              48 O
#                           hours O
#                              or O
#                            till O
#                           death O
#                              if O
#                         expired O
#                          during O
#              post-resuscitation B-treatment
#                     hypothermia I-treatment
#                         therapy I-treatment
#                               . O
# </description>
#   <condition>                       Cardiac B-problem
#                          Arrest I-problem
# </condition>
#   <inclusion_criteria>                 consciousness B-test
#                           level I-test
# ...
# 25102 error.. INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# 25103 error.. INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# 25104 error.. INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# <Doc nct_id="NCT00633542">
#   <title>                   Maintenance B-treatment
#                         Therapy I-treatment
#                           After O
#       Thalidomide-Dexamethasone B-treatment
#                               ( I-treatment
#                           ThaDD I-treatment
#                               ) I-treatment
#                             for O
#                        Multiple B-problem
#                         Myeloma I-problem
#                               ( I-problem
#                              MM I-problem
#                               ) I-problem
# </title>
#   <official_title>     Thalidomide-Dexamethasone B-treatment
#                              vs O
#  Alpha-Interferon-Dexamethasone B-treatment
#                              as O
#                     Maintenance B-treatment
#                         Therapy I-treatment
#                           After O
#                     Thalidomide B-treatment
#                               , O
#                   Dexamethasone B-treatment
#                             and O
#                       Pegylated B-treatment
#                       Liposomal I-treatment
#                     Doxorubicin I-treatment
#                     Combination I-treatment
#                             for O
# </official_title>
#   <summary>                      patients O
#                            with O
#                        multiple B-problem
#                         myeloma I-problem
#                             who O
#                       responded O
#                              to O
#                           ThaDD B-treatment
#                       induction I-treatment
#                         therapy I-treatment
# </summary>
#   <description>                         month O
#                               . O
# </description>
#   <condition>                      Multiple B-problem
#                         Myeloma I-problem
# </condition>
#   <inclusion_criteria>                             - O
#                         Written O
#                         consent O
# </inclusion_criteria>
#   <exclusion_criteria>                             - O
#                           organ B-problem
#                     disfunction I-problem
#                               &gt; O
#                           grade O
#                               2 O
# </exclusion_criteria>
# </Doc>
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# 25106 error.. INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# 25107 error.. INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# 25108 error.. INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# 25109 error.. INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# 25110 error.. INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# 25111 error.. INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# 25112 error.. INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# 25113 error.. INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# 25114 error.. INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# <Doc nct_id="NCT00635427">
#   <title>                            An B-test
#                      Open-Label I-test
#                       Extension I-test
#                           Study I-test
#                              of O
#                          GA-GCB B-treatment
#                             ERT I-treatment
#                              in O
#                        Patients O
#                            With O
#                            Type B-problem
#                               1 I-problem
#                         Gaucher I-problem
#                         Disease I-problem
# </title>
#   <official_title>                            An B-test
#                      Open-Label I-test
#                       Extension I-test
#                           Study I-test
#                              of O
#                 Gene-Activated® B-treatment
#                           Human I-treatment
#              Glucocerebrosidase I-treatment
#                               ( I-treatment
#                          GA-GCB I-treatment
#                               ) I-treatment
#                          Enzyme I-treatment
#                     Replacement I-treatment
#                         Therapy I-treatment
#                              in O
#                        Patients O
#                            With O
#                            Type B-problem
#                               1 I-problem
#                         Gaucher I-problem
#                         Disease I-problem
# </official_title>
#   <summary>                      patients O
#                            with O
#                            type B-problem
#                               1 I-problem
#                         Gaucher I-problem
#                         disease I-problem
#                               . O
# </summary>
#   <description>                           and O
#                        children O
#                            with O
#                            Type B-problem
#                               1 I-problem
#                         Gaucher I-problem
#                         disease I-problem
#                               . O
# </description>
#   <condition>                       Gaucher B-problem
#                         Disease I-problem
#                               , O
#                            Type B-problem
#                               1 I-problem
# </condition>
#   <inclusion_criteria>                        judged O
#                              by O
#                             the O
#                    Investigator O
# </inclusion_criteria>
#   <exclusion_criteria>                      unlikely O
#                              to O
#                        complete O
#                             the B-test
#                           study I-test
#                               , O
#                              as O
#                      determined O
#                              by O
#                             the O
#                    Investigator O
# </exclusion_criteria>
# </Doc>
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# <Doc nct_id="NCT00630383">
#   <title>              Immunoregulation B-treatment
#                              by O
#                      Controlled B-treatment
#                        Parasite I-treatment
#                        Exposure I-treatment
#                              in O
#                        Multiple B-problem
#                       Sclerosis I-problem
#                               . O
# </title>
#   <official_title>              Immunoregulation B-treatment
#                              by O
#                      Controlled B-treatment
#                        Parasite I-treatment
#                        Exposure I-treatment
#                              in O
#                        Multiple B-problem
#                       Sclerosis I-problem
#                               . O
# </official_title>
#   <summary>                            MS B-problem
#                               . O
# </summary>
#   <description>                  intervention B-treatment
#                              of O
#                     significant O
#                       potential O
#                               . O
# </description>
#   <condition>                      Multiple B-problem
#                       Sclerosis I-problem
# </condition>
#   <inclusion_criteria>                     screening B-test
#                           visit O
#                           prior O
#                              to O
#                             any B-treatment
#               protocol-specific I-treatment
#                      procedures I-treatment
#                       performed O
#                               . O
# </inclusion_criteria>
#   <exclusion_criteria>                     Treatment O
#                            with O
#                             any B-treatment
#                 investigational I-treatment
#                           agent I-treatment
#                          within O
#                              12 O
#                           weeks O
#                           prior O
#                              to O
#                        baseline O
# </exclusion_criteria>
# </Doc>
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# 25117 error.. INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# 25118 error.. INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# INFO:tensorflow:Restoring parameters from /home2/dalya/clinical_concept_extraction/clinical_concept_extraction/cce_assets/blstm/model
# 25119 error..

# %%
print (start)
